# %%
import os
import urllib.request
import zipfile
import nibabel as nib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, Subset, WeightedRandomSampler
from torchvision import transforms

from fastai.vision.all import *

from google.colab import drive

from tqdm.notebook import tqdm

# %% [markdown]
# #Brain Activity Patterns in Learning Processes
#
# a nerual network to classify different stages of learning (e.g., early, middle, late) based on fMRI data. This could provide insights into how the brain's activity changes as we acquire new skills or knowledge.
#
# dataset: [Classification learning](https://openfmri.org/dataset/ds000002/) from OpenfMRI

# %% [markdown]
# Download and extract the dataset

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
base_path = '/content/drive/MyDrive/learnedSpectrum'
zip_path = os.path.join(base_path, "ds000002_R2.0.5_raw.zip")
extract_path = os.path.join(base_path, "fmri_data")

# %%
url = "https://s3.amazonaws.com/openneuro/ds000002/ds000002_R2.0.5/compressed/ds000002_R2.0.5_raw.zip"

# %%
print("Downloading dataset...")
urllib.request.urlretrieve(url, zip_path)
# Out:
# Downloading dataset...
# ('/content/drive/MyDrive/learnedSpectrum/ds000002_R2.0.5_raw.zip',
#  <http.client.HTTPMessage at 0x7cd24559feb0>)

# %%
print("Extracting dataset...")
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)
# Out:
# Extracting dataset...

# %%
print("Dataset extracted to:", extract_path)
# Out:
# Dataset extracted to: /content/drive/MyDrive/learnedSpectrum/fmri_data

# %% [markdown]
# explore directory structure

# %%
def explore_directory(path, level=0):
    print("|   " * level + "+--" + os.path.basename(path))
    if os.path.isdir(path):
        for item in os.listdir(path):
            item_path = os.path.join(path, item)
            if os.path.isdir(item_path):
                explore_directory(item_path, level + 1)
            elif item.endswith('.nii.gz'):
                print("|   " * (level + 1) + "+--" + item)

# %%
print("\nDataset structure:")
explore_directory(extract_path)
# Out:
# Dataset structure:
# +--fmri_data
# |   +--ds002_R2.0.5
# |   |   +--sub-03
# |   |   |   +--anat
# |   |   |   |   +--sub-03_T1w.nii.gz
# |   |   |   |   +--sub-03_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-03_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-03_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-03_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-03_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-03_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-03_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   +--sub-08
# |   |   |   +--anat
# |   |   |   |   +--sub-08_T1w.nii.gz
# |   |   |   |   +--sub-08_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-08_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-08_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-08_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-08_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-08_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-08_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   +--sub-02
# |   |   |   +--anat
# |   |   |   |   +--sub-02_T1w.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-02_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-02_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-02_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-02_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-02_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-02_task-deterministicclassification_run-01_bold.nii.gz
# |   |   +--sub-07
# |   |   |   +--anat
# |   |   |   |   +--sub-07_T1w.nii.gz
# |   |   |   |   +--sub-07_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-07_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-07_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-07_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-07_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-07_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-07_task-deterministicclassification_run-02_bold.nii.gz
# |   |   +--sub-13
# |   |   |   +--anat
# |   |   |   |   +--sub-13_T1w.nii.gz
# |   |   |   |   +--sub-13_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-13_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-13_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-13_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-13_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-13_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-13_task-deterministicclassification_run-01_bold.nii.gz
# |   |   +--sub-01
# |   |   |   +--anat
# |   |   |   |   +--sub-01_T1w.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-01_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-01_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-01_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-01_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-01_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-01_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   +--sub-06
# |   |   |   +--anat
# |   |   |   |   +--sub-06_inplaneT2.nii.gz
# |   |   |   |   +--sub-06_T1w.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-06_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-06_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-06_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-06_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-06_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-06_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   +--sub-12
# |   |   |   +--anat
# |   |   |   |   +--sub-12_inplaneT2.nii.gz
# |   |   |   |   +--sub-12_T1w.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-12_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-12_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-12_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-12_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-12_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-12_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   +--sub-17
# |   |   |   +--anat
# |   |   |   |   +--sub-17_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-17_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-17_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-17_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-17_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-17_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-17_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   +--sub-05
# |   |   |   +--anat
# |   |   |   |   +--sub-05_T1w.nii.gz
# |   |   |   |   +--sub-05_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-05_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-05_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-05_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-05_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-05_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-05_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   +--sub-11
# |   |   |   +--anat
# |   |   |   |   +--sub-11_T1w.nii.gz
# |   |   |   |   +--sub-11_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-11_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-11_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-11_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-11_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-11_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-11_task-deterministicclassification_run-02_bold.nii.gz
# |   |   +--sub-16
# |   |   |   +--anat
# |   |   |   |   +--sub-16_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-16_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-16_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-16_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-16_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-16_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-16_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   +--derivatives
# |   |   |   +--mriqc
# |   |   +--sub-04
# |   |   |   +--anat
# |   |   |   |   +--sub-04_T1w.nii.gz
# |   |   |   |   +--sub-04_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-04_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-04_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-04_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-04_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-04_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-04_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   +--sub-09
# |   |   |   +--anat
# |   |   |   |   +--sub-09_T1w.nii.gz
# |   |   |   |   +--sub-09_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-09_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-09_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-09_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-09_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-09_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-09_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   +--sub-10
# |   |   |   +--anat
# |   |   |   |   +--sub-10_T1w.nii.gz
# |   |   |   |   +--sub-10_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-10_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-10_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-10_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-10_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-10_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-10_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   +--sub-15
# |   |   |   +--anat
# |   |   |   |   +--sub-15_T1w.nii.gz
# |   |   |   |   +--sub-15_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-15_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-15_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-15_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-15_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-15_task-deterministicclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-15_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   +--sub-14
# |   |   |   +--anat
# |   |   |   |   +--sub-14_T1w.nii.gz
# |   |   |   |   +--sub-14_inplaneT2.nii.gz
# |   |   |   +--func
# |   |   |   |   +--sub-14_task-mixedeventrelatedprobe_run-02_bold.nii.gz
# |   |   |   |   +--sub-14_task-deterministicclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-14_task-probabilisticclassification_run-02_bold.nii.gz
# |   |   |   |   +--sub-14_task-mixedeventrelatedprobe_run-01_bold.nii.gz
# |   |   |   |   +--sub-14_task-probabilisticclassification_run-01_bold.nii.gz
# |   |   |   |   +--sub-14_task-deterministicclassification_run-01_bold.nii.gz

# %% [markdown]
# load and display basic info about NIfTI files

# %%
def display_nifti_info(file_path):
    img = nib.load(file_path)
    print(f"File: {os.path.basename(file_path)}")
    print(f"Shape: {img.shape}")
    print(f"Data type: {img.get_data_dtype()}")
    print(f"Header info:")
    print(img.header)
    print("\n")

# %% [markdown]
# Display info for a sample NIfTI file

# %%
sample_nifti = None
for root, dirs, files in os.walk(extract_path):
    for file in files:
        if file.endswith('.nii.gz'):
            sample_nifti = os.path.join(root, file)
            break
    if sample_nifti:
        break

if sample_nifti:
    print("\nSample NIfTI file info:")
    display_nifti_info(sample_nifti)
else:
    print("No NIfTI files found in the dataset.")
# Out:
# Sample NIfTI file info:
# File: sub-03_T1w.nii.gz
# Shape: (160, 192, 192)
# Data type: int16
# Header info:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b''
# dim_info        : 0
# dim             : [  3 160 192 192   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : int16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [-1.         1.         1.3333333  1.3333333  0.         1.
#   1.         1.       ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 10
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b'FreeSurfer Aug 11 2009'
# aux_file        : b''
# qform_code      : scanner
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : 1.0
# quatern_d       : 0.0
# qoffset_x       : 80.0
# qoffset_y       : -127.99999
# qoffset_z       : -127.99999
# srow_x          : [-1.  0.  0. 80.]
# srow_y          : [   0.           1.3333333    0.        -127.99999  ]
# srow_z          : [   0.           0.           1.3333333 -127.99999  ]
# intent_name     : b''
# magic           : b'n+1'

# %% [markdown]
# Data augmentation

# %%
class RandomNoise(object):
    def __init__(self, mean=0, std=0.1):
        self.std = std
        self.mean = mean

    def __call__(self, tensor):
        return tensor + torch.randn(tensor.size()) * self.std + self.mean

    def __repr__(self):
        return self.__class__.__name__ + '(mean={0}, std={1})'.format(self.mean, self.std)

# %% [markdown]
# Define preprocessing function

# %%
def preprocess_fmri(img):
    try:
        print(f"Original shape: {img.shape}")

        if len(img.shape) != 4:
            raise ValueError(f"Expected 4D input, got {len(img.shape)}D")

        if img.shape[3] == 0:
            img = np.zeros(img.shape[:3] + (1,))

        mean = img.mean(axis=3, keepdims=True)
        std = img.std(axis=3, keepdims=True)
        img = (img - mean) / (std + 1e-8)

        img = img.mean(axis=3)

        target_shape = (64, 64, 64)
        current_shape = img.shape

        pad_width = []
        for t, c in zip(target_shape, current_shape):
            if t > c:
                pad_before = (t - c) // 2
                pad_after = t - c - pad_before
                pad_width.append((pad_before, pad_after))
            elif t < c:
                crop_before = (c - t) // 2
                crop_after = c - t - crop_before
                pad_width.append((-crop_before, -crop_after))
            else:
                pad_width.append((0, 0))

        img = np.pad(img, pad_width, mode='constant', constant_values=0)

        img = img[:64, :64, :64]

        img = img[np.newaxis, ...]

        img_tensor = torch.from_numpy(img).float()

        print(f"Processed shape: {img_tensor.shape}")
        return img_tensor

    except Exception as e:
        print(f"Error in preprocess_fmri: {str(e)}")
        return torch.zeros((1, 64, 64, 64))

# %% [markdown]
# Define the fMRIDataset class

# %%
class fMRIDataset(Dataset):
    def __init__(self, root_dir):
        self.root_dir = os.path.join(root_dir, 'ds002_R2.0.5')
        self.samples = self._load_samples()

    def _load_samples(self):
        samples = []
        for subject in os.listdir(self.root_dir):
            subject_path = os.path.join(self.root_dir, subject)
            if os.path.isdir(subject_path) and subject.startswith('sub-'):
                func_path = os.path.join(subject_path, 'func')
                if os.path.exists(func_path):
                    nifti_files = [f for f in os.listdir(func_path) if f.endswith('_bold.nii.gz')]
                    for file in nifti_files:
                        file_path = os.path.join(func_path, file)
                        task = file.split('task-')[1].split('_')[0]
                        run = int(file.split('run-')[1].split('_')[0])

                        if 'deterministic' in task:
                            label = 0
                        elif 'probabilistic' in task:
                            label = 1
                        else:
                            label = 2

                        samples.append((file_path, label, task))
        return samples

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        file_path, label, task = self.samples[idx]
        try:
            img = nib.load(file_path).get_fdata()
            img = preprocess_fmri(img)
            return img, label, task
        except Exception as e:
            print(f"Error loading {file_path}: {str(e)}")
            # Return a dummy sample in case of error
            return torch.zeros((1, 64, 64, 64)), -1, "error"

# %%
root_dir = '/content/drive/MyDrive/learnedSpectrum/fmri_data'
dataset = fMRIDataset(root_dir=root_dir)

print(f"Dataset length: {len(dataset)}")
# Out:
# Dataset length: 102

# %%
for i in range(min(5, len(dataset))):
    try:
        img, label, task = dataset[i]
        print(f"Sample {i}:")
        print(f"  Image shape: {img.shape}")
        if img.numel() > 0:
            print(f"  Image min: {img.min().item():.4f}, max: {img.max().item():.4f}, mean: {img.mean().item():.4f}, std: {img.std().item():.4f}")
        else:
            print("  Image is empty")
        print(f"  Label: {label}")
        print(f"  Task: {task}")
    except Exception as e:
        print(f"Error loading sample {i}: {str(e)}")
# Out:
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Sample 0:
#   Image shape: torch.Size([1, 64, 64, 64])
#   Image min: -0.0000, max: 0.0000, mean: 0.0000, std: 0.0000
#   Label: 2
#   Task: mixedeventrelatedprobe
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Sample 1:
#   Image shape: torch.Size([1, 64, 64, 64])
#   Image min: -0.0000, max: 0.0000, mean: -0.0000, std: 0.0000
#   Label: 1
#   Task: probabilisticclassification
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Sample 2:
#   Image shape: torch.Size([1, 64, 64, 64])
#   Image min: -0.0000, max: 0.0000, mean: 0.0000, std: 0.0000
#   Label: 2
#   Task: mixedeventrelatedprobe
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Sample 3:
#   Image shape: torch.Size([1, 64, 64, 64])
#   Image min: -0.0000, max: 0.0000, mean: -0.0000, std: 0.0000
#   Label: 0
#   Task: deterministicclassification
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Sample 4:
#   Image shape: torch.Size([1, 64, 64, 64])
#   Image min: -0.0000, max: 0.0000, mean: -0.0000, std: 0.0000
#   Label: 0
#   Task: deterministicclassification

# %%
batch_size = 4
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

print("\nTesting DataLoader:")
for i, (batch_img, batch_label, batch_task) in enumerate(dataloader):
    print(f"Batch {i}:")
    print(f"  Batch image shape: {batch_img.shape}")
    if batch_img.numel() > 0:
        print(f"  Batch image min: {batch_img.min().item():.4f}, max: {batch_img.max().item():.4f}, mean: {batch_img.mean().item():.4f}, std: {batch_img.std().item():.4f}")
    else:
        print("  Batch image is empty")
    print(f"  Batch label shape: {batch_label.shape}")
    print(f"  Batch task: {batch_task}")
    if i == 2:
        break
# Out:
# Testing DataLoader:
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Batch 0:
#   Batch image shape: torch.Size([4, 1, 64, 64, 64])
#   Batch image min: -0.0000, max: 0.0000, mean: 0.0000, std: 0.0000
#   Batch label shape: torch.Size([4])
#   Batch task: ('mixedeventrelatedprobe', 'deterministicclassification', 'probabilisticclassification', 'deterministicclassification')
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Batch 1:
#   Batch image shape: torch.Size([4, 1, 64, 64, 64])
#   Batch image min: -0.0000, max: 0.0000, mean: -0.0000, std: 0.0000
#   Batch label shape: torch.Size([4])
#   Batch task: ('mixedeventrelatedprobe', 'mixedeventrelatedprobe', 'mixedeventrelatedprobe', 'mixedeventrelatedprobe')
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Batch 2:
#   Batch image shape: torch.Size([4, 1, 64, 64, 64])
#   Batch image min: -0.0000, max: 0.0000, mean: -0.0000, std: 0.0000
#   Batch label shape: torch.Size([4])
#   Batch task: ('mixedeventrelatedprobe', 'mixedeventrelatedprobe', 'deterministicclassification', 'deterministicclassification')

# %% [markdown]
# Define the 3D CNN model

# %%
class ImprovedFMRICNN(nn.Module):
    def __init__(self, num_classes):
        super(ImprovedFMRICNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv3d(1, 32, kernel_size=3, padding=1),
            nn.BatchNorm3d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=2, stride=2),

            nn.Conv3d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm3d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=2, stride=2),

            nn.Conv3d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm3d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool3d(kernel_size=2, stride=2),
        )

        self.classifier = nn.Sequential(
            nn.Linear(128 * 8 * 8 * 8, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %% [markdown]
# Learning rate scheduler

# %%
def get_lr_scheduler(optimizer):
    return optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)

# %% [markdown]
# Early stopping

# %%
class EarlyStopping:
    def __init__(self, patience=7, verbose=False, delta=0):
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta

    def __call__(self, val_loss, model):
        score = -val_loss
        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            if self.verbose:
                print(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        if self.verbose:
            print(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}). Saving model ...')
        torch.save(model.state_dict(), 'checkpoint.pt')
        self.val_loss_min = val_loss

# %% [markdown]
# Training function

# %%
def train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device, scheduler):
    model.to(device)
    best_val_acc = 0.0
    best_model = None

    for epoch in range(num_epochs):
        model.train()
        train_loss = 0.0
        train_correct = 0
        train_total = 0

        for inputs, labels, _ in tqdm(train_loader, desc=f"Epoch {epoch+1}/{num_epochs}"):
            inputs, labels = inputs.to(device), labels.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * inputs.size(0)
            _, predicted = outputs.max(1)
            train_total += labels.size(0)
            train_correct += predicted.eq(labels).sum().item()

        train_loss = train_loss / len(train_loader.dataset)
        train_acc = train_correct / train_total

        model.eval()
        val_loss = 0.0
        val_correct = 0
        val_total = 0

        with torch.no_grad():
            for inputs, labels, _ in val_loader:
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = model(inputs)
                loss = criterion(outputs, labels)

                val_loss += loss.item() * inputs.size(0)
                _, predicted = outputs.max(1)
                val_total += labels.size(0)
                val_correct += predicted.eq(labels).sum().item()

        val_loss = val_loss / len(val_loader.dataset)
        val_acc = val_correct / val_total

        print(f'Epoch {epoch+1}/{num_epochs}:')
        print(f'Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}')
        print(f'Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

        scheduler.step(val_loss)

        if val_acc > best_val_acc:
            best_val_acc = val_acc
            best_model = model.state_dict()

    model.load_state_dict(best_model)
    return model

# %%
print("First few samples:")
for i in range(min(5, len(dataset))):
    print(f"Sample {i}: {dataset.samples[i]}")

if len(dataset) == 0:
    print("Error: The dataset is empty. Please check the following:")
    print(f"1. The root_dir '{root_dir}' exists and contains the 'ds002_R2.0.5' folder.")
    print("2. The directory structure matches what's expected in the _load_samples method.")
    print("3. There are .nii.gz files in the func subdirectories.")
# Out:
# First few samples:
# Sample 0: ('/content/drive/MyDrive/learnedSpectrum/fmri_data/ds002_R2.0.5/sub-03/func/sub-03_task-mixedeventrelatedprobe_run-01_bold.nii.gz', 2, 'mixedeventrelatedprobe')
# Sample 1: ('/content/drive/MyDrive/learnedSpectrum/fmri_data/ds002_R2.0.5/sub-03/func/sub-03_task-probabilisticclassification_run-01_bold.nii.gz', 1, 'probabilisticclassification')
# Sample 2: ('/content/drive/MyDrive/learnedSpectrum/fmri_data/ds002_R2.0.5/sub-03/func/sub-03_task-mixedeventrelatedprobe_run-02_bold.nii.gz', 2, 'mixedeventrelatedprobe')
# Sample 3: ('/content/drive/MyDrive/learnedSpectrum/fmri_data/ds002_R2.0.5/sub-03/func/sub-03_task-deterministicclassification_run-01_bold.nii.gz', 0, 'deterministicclassification')
# Sample 4: ('/content/drive/MyDrive/learnedSpectrum/fmri_data/ds002_R2.0.5/sub-03/func/sub-03_task-deterministicclassification_run-02_bold.nii.gz', 0, 'deterministicclassification')

# %% [markdown]
# Balance the dataset

# %%
label_counts = [0, 0, 0]
for _, label, _ in dataset:
    if label != -1:
        label_counts[label] += 1

class_weights = [len(dataset) / (3 * count) for count in label_counts]
sample_weights = [class_weights[label] if label != -1 else 0 for _, label, _ in dataset]
# Out:
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])

# %% [markdown]
# Split the data

# %%
indices = list(range(len(dataset)))

# %%
train_val_indices, test_indices = train_test_split(indices, test_size=0.2, random_state=42)
train_indices, val_indices = train_test_split(train_val_indices, test_size=0.2, random_state=42)

# %% [markdown]
# weighted samplers

# %%
train_sampler = WeightedRandomSampler([sample_weights[i] for i in train_indices], len(train_indices))
val_sampler = WeightedRandomSampler([sample_weights[i] for i in val_indices], len(val_indices))

# %% [markdown]
# data loaders

# %%
batch_size = 16
train_loader = DataLoader(dataset, batch_size=batch_size, sampler=train_sampler, num_workers=2)
val_loader = DataLoader(dataset, batch_size=batch_size, sampler=val_sampler, num_workers=2)
test_loader = DataLoader(dataset, batch_size=batch_size, sampler=test_indices, num_workers=2)

# %% [markdown]
# Initialize model, loss, and optimizer

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ImprovedFMRICNN(num_classes=3)
criterion = nn.CrossEntropyLoss(weight=torch.tensor(class_weights).to(device))
optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:60: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %% [markdown]
# Train the model

# %%
num_epochs = 50
trained_model = train_model(model, train_loader, val_loader, criterion, optimizer, num_epochs, device, scheduler)
# Out:
# Epoch 1/50:   0%|          | 0/7 [00:00<?, ?it/s]
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Epoch 1/50:
# Train Loss: 1.0988, Train Acc: 0.3333
# Val Loss: 1.1004, Val Acc: 0.3333
# Epoch 2/50:   0%|          | 0/7 [00:00<?, ?it/s]
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Original shape: (64, 64, 25, 237)
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Original shape: (64, 64, 30, 232)
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Epoch 2/50:
# Train Loss: 1.4073, Train Acc: 0.3235
# Val Loss: 1.2435, Val Acc: 0.3333
# Epoch 3/50:   0%|          | 0/7 [00:00<?, ?it/s]
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)Original shape: (64, 64, 30, 232)
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)Processed shape: torch.Size([1, 64, 64, 64])
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)Processed shape: torch.Size([1, 64, 64, 64])
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 25, 180)Processed shape: torch.Size([1, 64, 64, 64])
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# ...
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)Original shape: (64, 64, 30, 180)
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)Original shape: (64, 64, 25, 237)
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)Processed shape: torch.Size([1, 64, 64, 64])
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Epoch 50/50:
# Train Loss: 1.0988, Train Acc: 0.3235
# Val Loss: 1.0987, Val Acc: 0.3333

# %% [markdown]
# Evaluate the model

# %%
trained_model.eval()
all_preds = []
all_labels = []
all_tasks = []

with torch.no_grad():
    for inputs, labels, tasks in tqdm(test_loader, desc="Evaluating"):
        inputs, labels = inputs.to(device), labels.to(device)
        outputs = trained_model(inputs)
        _, predicted = outputs.max(1)
        all_preds.extend(predicted.cpu().numpy())
        all_labels.extend(labels.cpu().numpy())
        all_tasks.extend(tasks)
# Out:
# Evaluating:   0%|          | 0/7 [00:00<?, ?it/s]
# Original shape: (64, 64, 25, 237)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])Original shape: (64, 64, 30, 180)
#
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 25, 237)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 232)
# Original shape: (64, 64, 30, 232)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])Processed shape: torch.Size([1, 64, 64, 64])
#
# Original shape: (64, 64, 30, 180)
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 234)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])
# Original shape: (64, 64, 30, 180)
# Processed shape: torch.Size([1, 64, 64, 64])

# %% [markdown]
# Print classification report

# %%
print(classification_report(all_labels, all_preds, target_names=['Deterministic', 'Probabilistic', 'Mixed']))
# Out:
#                precision    recall  f1-score   support
#
# Deterministic       0.33      1.00      0.50        34
# Probabilistic       0.00      0.00      0.00        34
#         Mixed       0.00      0.00      0.00        34
#
#      accuracy                           0.33       102
#     macro avg       0.11      0.33      0.17       102
#  weighted avg       0.11      0.33      0.17       102
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
